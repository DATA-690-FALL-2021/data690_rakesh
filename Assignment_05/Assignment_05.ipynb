# %% [markdown]
# <a href="https://colab.research.google.com/github/rakeshp1/data690_rakesh/blob/main/Assignment_05/Assignment_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment_05
# #Rakesh
# #690 Fall - Dr.Wang

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('MERGED2017_18_PP.csv')

# %% [markdown]
# #1. How many colleges or rows?

# %%
data.shape[0]
# Out:
# 7112

# %% [markdown]
# #2.How many variables or columns?

# %%
data.shape[1]
# Out:
# 1986

# %%
data.shape
# Out:
# (7112, 1986)

# %% [markdown]
# #3. Look at the first 5 colleges

# %%
data.head()
# Out:
#    UNITID    OPEID  ...  FTFTPCTFLOAN_POOLED_SUPP SCUGFFN_POOLED
# 0  100654   100200  ...                       NaN            NaN
# 1  100663   105200  ...                       NaN            NaN
# 2  100690  2503400  ...                       NaN            NaN
# 3  100706   105500  ...                       NaN            NaN
# 4  100724   100500  ...                       NaN            NaN
#
# [5 rows x 1986 columns]

# %% [markdown]
# #4. Look at the last 5 colleges

# %%
data.tail()
# Out:
#         UNITID    OPEID  ...  FTFTPCTFLOAN_POOLED_SUPP SCUGFFN_POOLED
# 7107  48312404   108163  ...                       NaN            NaN
# 7108  48387801  4223701  ...                       NaN            NaN
# 7109  48400201  4228101  ...                       NaN            NaN
# 7110  48778201  4221501  ...                       NaN            NaN
# 7111  49005401  4182601  ...                       NaN            NaN
#
# [5 rows x 1986 columns]

# %% [markdown]
# #5. Look at a random sample of 5 colleges

# %%
data.sample(n=5)
# Out:
#       UNITID    OPEID  ...  FTFTPCTFLOAN_POOLED_SUPP SCUGFFN_POOLED
# 297   114123   903200  ...                       NaN            NaN
# 749   136783   910400  ...                       NaN            NaN
# 4143  366401  3035700  ...                       NaN            NaN
# 11    101028  1218200  ...                       NaN            NaN
# 5878  461944  4184700  ...                       NaN            NaN
#
# [5 rows x 1986 columns]

# %% [markdown]
# #Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook in a Markdown cell so that the readers of your notebook will know the meaning of these variables.

# %% [markdown]
# #ID:
# ###source: UNITID
#
# ###description: Unit ID for institution

# %% [markdown]
# #school.name:
# ###source: INSTNM
# ###description: Institution name

# %% [markdown]
# #school.city:
# ###source: CITY
# ###description: City

# %% [markdown]
# #school.state:
# ###source: STABBR
# ###description: State postcode

# %% [markdown]
# #school.zip:
# ###source: ZIP
# ###description: ZIP code

# %% [markdown]
# #admissions.admission_rate.overall:
# ###source: ADM_RATE
# ###description: Admission rate

# %% [markdown]
# #student.size:
# ###source: UGDS
# ###description: Enrollment of undergraduate certificate/degree-seeking students

# %% [markdown]
# #cost.tuition.in_state:
# ###source: TUITIONFEE_IN
# ###description: In-state tuition and fees

# %% [markdown]
# #earnings.10_yrs_after_entryworking_not_enrolled.mean_earnings:
# ###source: MN_EARN_WNE_P10
# ###description: Mean earnings of students working and not enrolled 10 years after

# %% [markdown]
# #Part - B
# #  smaller data frame

# %%
data1=data[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]

# %% [markdown]
# #1. Look at the first 10 colleges

# %%
data1.head(10)
# Out:
#    UNITID                               INSTNM  ... TUITIONFEE_IN MN_EARN_WNE_P10
# 0  100654             Alabama A & M University  ...        9857.0             NaN
# 1  100663  University of Alabama at Birmingham  ...        8328.0             NaN
# 2  100690                   Amridge University  ...        6900.0             NaN
# 3  100706  University of Alabama in Huntsville  ...       10280.0             NaN
# 4  100724             Alabama State University  ...       11068.0             NaN
# 5  100751            The University of Alabama  ...       10780.0             NaN
# 6  100760    Central Alabama Community College  ...        4440.0             NaN
# 7  100812              Athens State University  ...           NaN             NaN
# 8  100830      Auburn University at Montgomery  ...        8020.0             NaN
# 9  100858                    Auburn University  ...       10968.0             NaN
#
# [10 rows x 9 columns]

# %% [markdown]
# #2. look at the last 10 colleges

# %%
data1.tail(10)
# Out:
#         UNITID  ... MN_EARN_WNE_P10
# 7102  48154401  ...             NaN
# 7103  48305401  ...             NaN
# 7104  48312401  ...             NaN
# 7105  48312402  ...             NaN
# 7106  48312403  ...             NaN
# 7107  48312404  ...             NaN
# 7108  48387801  ...             NaN
# 7109  48400201  ...             NaN
# 7110  48778201  ...             NaN
# 7111  49005401  ...             NaN
#
# [10 rows x 9 columns]

# %% [markdown]
# #3. Look at a random sample of 10 colleges

# %%
data1.sample(n=10)
# Out:
#         UNITID  ... MN_EARN_WNE_P10
# 4708    431558  ...             NaN
# 736     136215  ...             NaN
# 4508    416801  ...             NaN
# 511     125499  ...             NaN
# 1904    177968  ...             NaN
# 5505    455558  ...             NaN
# 6942  23693902  ...             NaN
# 5263    449269  ...             NaN
# 1205    154129  ...             NaN
# 5313    450067  ...             NaN
#
# [10 rows x 9 columns]

# %% [markdown]
# #4. Find and display UMBC

# %%
data1[data1['INSTNM'].str.contains("University of Maryland-Baltimore County")]
# Out:
#       UNITID  ... MN_EARN_WNE_P10
# 1478  163268  ...             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# #5. Find Univ. of Maryland College Park

# %%
data1[data1['INSTNM'].str.contains("University of Maryland-College Park")]
# Out:
#       UNITID  ... MN_EARN_WNE_P10
# 1479  163286  ...             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# #6. Find and display Loyola College Maryland

# %%
data1[data1['INSTNM'].str.contains("Loyola University Maryland")]
# Out:
#       UNITID                      INSTNM  ... TUITIONFEE_IN MN_EARN_WNE_P10
# 1475  163046  Loyola University Maryland  ...       47560.0             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# #7. Find and display Johns Hopskins

# %%
data1[data1['INSTNM'].str.contains("Johns Hopkins")]
# Out:
#       UNITID                    INSTNM  ... TUITIONFEE_IN MN_EARN_WNE_P10
# 1473  162928  Johns Hopkins University  ...       52170.0             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# #8. Calculate the min, max, and average in-state tution of the above four institutions.

# %%
data1[data1['INSTNM'].str.contains("University of Maryland-Baltimore County")]['TUITIONFEE_IN'].describe()
# Out:
# count        1.0
# mean     11518.0
# std          NaN
# min      11518.0
# 25%      11518.0
# 50%      11518.0
# 75%      11518.0
# max      11518.0
# Name: TUITIONFEE_IN, dtype: float64

# %%
data1[data1['INSTNM'].str.contains("University of Maryland-College Park")]['TUITIONFEE_IN'].describe()
# Out:
# count        1.0
# mean     10399.0
# std          NaN
# min      10399.0
# 25%      10399.0
# 50%      10399.0
# 75%      10399.0
# max      10399.0
# Name: TUITIONFEE_IN, dtype: float64

# %%
data1[data1['INSTNM'].str.contains("Loyola University Maryland")]['TUITIONFEE_IN'].describe()
# Out:
# count        1.0
# mean     47560.0
# std          NaN
# min      47560.0
# 25%      47560.0
# 50%      47560.0
# 75%      47560.0
# max      47560.0
# Name: TUITIONFEE_IN, dtype: float64

# %%
data1[data1['INSTNM'].str.contains("Johns Hopkins")]['TUITIONFEE_IN'].describe()
# Out:
# count        1.0
# mean     52170.0
# std          NaN
# min      52170.0
# 25%      52170.0
# 50%      52170.0
# 75%      52170.0
# max      52170.0
# Name: TUITIONFEE_IN, dtype: float64

# %% [markdown]
# #9. Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis. Upload this file to your GitHub along with the notebook.

# %%
data2=data1[data1['STABBR'].isin(['MD', 'VA','DC','DE','PN'])]
data2
# Out:
#         UNITID  ... MN_EARN_WNE_P10
# 634     130837  ...             NaN
# 635     130873  ...             NaN
# 636     130907  ...             NaN
# 637     130934  ...             NaN
# 638     130943  ...             NaN
# ...        ...  ...             ...
# 7005  43018402  ...             NaN
# 7006  43018403  ...             NaN
# 7007  43018404  ...             NaN
# 7084  47503303  ...             NaN
# 7094  47503313  ...             NaN
#
# [312 rows x 9 columns]

# %%
data2.to_csv('Five_States_Colleges.csv')
