# %% [markdown]
# <a href="https://colab.research.google.com/github/rakeshp1/data690_rakesh/blob/main/Individual%20project%20part-B/Individual_Project_Part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rakeshp1/data690_rakesh/main/Individual%20project%20part-B/wdi_data%20(4).csv")
df.head()
# Out:
#    Unnamed: 0  Year  ...  Income Group    Lending Type
# 0           0  2010  ...   High income  Not classified
# 1           1  2011  ...   High income  Not classified
# 2           2  2012  ...   High income  Not classified
# 3           3  2013  ...   High income  Not classified
# 4           4  2014  ...   High income  Not classified
#
# [5 rows x 9 columns]

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#      Year      value  ... Income Group    Lending Type
# 0    2010  25.151417  ...  High income  Not classified
# 1    2011  26.436128  ...  High income  Not classified
# 2    2012  26.284164  ...  High income  Not classified
# 3    2013  25.127985  ...  High income  Not classified
# 4    2014  25.514817  ...  High income  Not classified
# ..    ...        ...  ...          ...             ...
# 265  2014   9.390405  ...  High income  Not classified
# 266  2015   9.352790  ...  High income  Not classified
# 267  2016   9.124074  ...  High income  Not classified
# 268  2017   9.110930  ...  High income  Not classified
# 269  2018   8.971459  ...  High income  Not classified
#
# [270 rows x 8 columns]

# %%
df_ind = df[df["Country Name"]=='India']
df_ind.head()
# Out:
#     Year      value  ...         Income Group Lending Type
# 9   2010  30.725078  ...  Lower middle income         IBRD
# 10  2011  30.161680  ...  Lower middle income         IBRD
# 11  2012  29.398528  ...  Lower middle income         IBRD
# 12  2013  28.404900  ...  Lower middle income         IBRD
# 13  2014  27.656401  ...  Lower middle income         IBRD
#
# [5 rows x 8 columns]

# %%
df_uk = df[df["Country Name"]=='United Kingdom']
df_uk.head()
# Out:
#     Year      value  ... Income Group    Lending Type
# 36  2010  18.991835  ...  High income  Not classified
# 37  2011  18.716302  ...  High income  Not classified
# 38  2012  18.690537  ...  High income  Not classified
# 39  2013  18.931033  ...  High income  Not classified
# 40  2014  18.547156  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
df_aus = df[df["Country Name"]=='Australia']
df_aus.head()
# Out:
#    Year      value  ... Income Group    Lending Type
# 0  2010  25.151417  ...  High income  Not classified
# 1  2011  26.436128  ...  High income  Not classified
# 2  2012  26.284164  ...  High income  Not classified
# 3  2013  25.127985  ...  High income  Not classified
# 4  2014  25.514817  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
df_Lanka = df[df["Country Name"]=='Sri Lanka']
df_Lanka.head()
# Out:
#     Year      value  ...         Income Group Lending Type
# 18  2010  26.644146  ...  Lower middle income         IBRD
# 19  2011  27.995667  ...  Lower middle income         IBRD
# 20  2012  30.126276  ...  Lower middle income         IBRD
# 21  2013  29.162758  ...  Lower middle income         IBRD
# 22  2014  28.297999  ...  Lower middle income         IBRD
#
# [5 rows x 8 columns]

# %%
df_swit = df[df["Country Name"]=='Switzerland']
df_swit.head()
# Out:
#     Year      value  ... Income Group    Lending Type
# 27  2010  24.921865  ...  High income  Not classified
# 28  2011  25.279568  ...  High income  Not classified
# 29  2012  24.874741  ...  High income  Not classified
# 30  2013  24.959493  ...  High income  Not classified
# 31  2014  24.622579  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
frames=[df_ind,df_uk,df_aus,df_Lanka,df_swit]
result= pd.concat(frames)
result
# Out:
#      Year      value  ...         Income Group    Lending Type
# 9    2010  30.725078  ...  Lower middle income            IBRD
# 10   2011  30.161680  ...  Lower middle income            IBRD
# 11   2012  29.398528  ...  Lower middle income            IBRD
# 12   2013  28.404900  ...  Lower middle income            IBRD
# 13   2014  27.656401  ...  Lower middle income            IBRD
# ..    ...        ...  ...                  ...             ...
# 256  2014  17.919881  ...          High income  Not classified
# 257  2015  17.474396  ...          High income  Not classified
# 258  2016  17.771376  ...          High income  Not classified
# 259  2017  17.858688  ...          High income  Not classified
# 260  2018  18.005902  ...          High income  Not classified
#
# [270 rows x 8 columns]

# %%
df_2018 = result.query("Year == 2018")
df_2018.sample(10)
# Out:
#      Year         value  ...         Income Group    Lending Type
# 17   2018     26.382899  ...  Lower middle income            IBRD
# 215  2018     66.155655  ...          High income  Not classified
# 152  2018   6705.149015  ...  Lower middle income            IBRD
# 161  2018  13238.388344  ...  Lower middle income            IBRD
# 260  2018     18.005902  ...          High income  Not classified
# 269  2018      8.971459  ...          High income  Not classified
# 71   2018     14.759963  ...  Lower middle income            IBRD
# 206  2018     23.038523  ...  Lower middle income            IBRD
# 8    2018     24.158967  ...          High income  Not classified
# 197  2018     19.941241  ...  Lower middle income            IBRD
#
# [10 rows x 8 columns]

# %%
df_2018 = df_2018.query("indicator in ['NE.EXP.GNFS.ZS','NV.IND.MANF.ZS','NV.IND.TOTL.ZS','BG.GSR.NFSV.GD.ZS','NV.AGR.TOTL.ZS','NY.GDP.PCAP.PP.CD']"	)
df_2018.head()
# Out:
#      Year        value  ...         Income Group Lending Type
# 17   2018    26.382899  ...  Lower middle income         IBRD
# 62   2018    12.185249  ...  Lower middle income         IBRD
# 107  2018    15.970157  ...  Lower middle income         IBRD
# 152  2018  6705.149015  ...  Lower middle income         IBRD
# 197  2018    19.941241  ...  Lower middle income         IBRD
#
# [5 rows x 8 columns]

# %%
df_pivot = df_2018.pivot(index =['Country Code','Country Name','Region','Income Group','Lending Type','Year'], columns='indicator', values='value').reset_index()
df_pivot.head()
# Out:
# indicator Country Code    Country Name  ... NV.IND.TOTL.ZS NY.GDP.PCAP.PP.CD
# 0                  AUS       Australia  ...      24.158967      50252.840457
# 1                  CHE     Switzerland  ...      24.670383      68709.444183
# 2                  GBR  United Kingdom  ...      18.124542      47145.884098
# 3                  IND           India  ...      26.382899       6705.149015
# 4                  LKA       Sri Lanka  ...      26.257035      13238.388344
#
# [5 rows x 12 columns]

# %%
df_pivot
# Out:
# indicator Country Code    Country Name  ... NV.IND.TOTL.ZS NY.GDP.PCAP.PP.CD
# 0                  AUS       Australia  ...      24.158967      50252.840457
# 1                  CHE     Switzerland  ...      24.670383      68709.444183
# 2                  GBR  United Kingdom  ...      18.124542      47145.884098
# 3                  IND           India  ...      26.382899       6705.149015
# 4                  LKA       Sri Lanka  ...      26.257035      13238.388344
#
# [5 rows x 12 columns]

# %%
df2 = df.query("indicator in ['NE.EXP.GNFS.ZS','NV.IND.MANF.ZS','NV.IND.TOTL.ZS','BG.GSR.NFSV.GD.ZS','NV.AGR.TOTL.ZS','NY.GDP.PCAP.PP.CD']")
df_pivot2 = df2.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot2.head()
# Out:
# indicator  Year Country Code  ... NV.IND.TOTL.ZS NY.GDP.PCAP.PP.CD
# 0          2010          AUS  ...      25.151417      39301.341120
# 1          2010          CHE  ...      24.921865      53112.424584
# 2          2010          GBR  ...      18.991835      36464.482568
# 3          2010          IND  ...      30.725078       4236.744348
# 4          2010          LKA  ...      26.644146       8194.269254
#
# [5 rows x 12 columns]

# %% [markdown]
# # Exports of goods and services (% of GDP) contribution to Economy growth:

# %%
fig = px.line(df_pivot2,
    x="Year",
    y="NE.EXP.GNFS.ZS",
    title="TOP 10 Countries by Exports of goods and services (% of GDP)",
    color='Country Name',
    labels={"Year":"Year","NE.EXP.GNFS.ZS":"Exports of goods and services (% of GDP)"},
    hover_name='Country Code')
#fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="27cabb71-6312-4f9e-83e4-136c5bbfacfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27cabb71-6312-4f9e-83e4-136c5bbfacfb")) {
#                     Plotly.newPlot(
#                         '27cabb71-6312-4f9e-83e4-136c5bbfacfb',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>Year=%{x}<br>Exports of goods and services (% of GDP)=%{y}", "hovertext": ["AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS"], "legendgroup": "Country Name=Australia", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Country Name=Australia", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [19.8100077543, 21.4364170541, 21.480828406, 19.9561676149, 21.039454999300002, 19.9848455098, 19.2510570755, 21.205750662, 21.8219046176], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Switzerland<br>Year=%{x}<br>Exports of goods and services (% of GDP)=%{y}", "hovertext": ["CHE", "CHE", "CHE", "CHE", "CHE", "CHE", "CHE", "CHE", "CHE"], "legendgroup": "Country Name=Switzerland", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Country Name=Switzerland", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [64.3985351676, 65.8992878988, 67.4064519955, 71.38153932670001, 63.8096991388, 62.396769875299995, 65.6736930688, 65.0797829663, 66.1556552661], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Kingdom<br>Year=%{x}<br>Exports of goods and services (% of GDP)=%{y}", "hovertext": ["GBR", "GBR", "GBR", "GBR", "GBR", "GBR", "GBR", "GBR", "GBR"], "legendgroup": "Country Name=United Kingdom", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Country Name=United Kingdom", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [28.2500231939, 30.713656249699998, 29.987498320500002, 29.870204276, 28.1976244869, 27.2637435854, 28.237058783400002, 30.1083210836, 30.890067756300002], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>Exports of goods and services (% of GDP)=%{y}", "hovertext": ["IND", "IND", "IND", "IND", "IND", "IND", "IND", "IND", "IND"], "legendgroup": "Country Name=India", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [22.4009332488, 24.5404113196, 24.5344306614, 25.430861300500002, 22.9679630081, 19.8131891564, 19.1582349106, 18.7917648393, 19.9412406764], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Sri Lanka<br>Year=%{x}<br>Exports of goods and services (% of GDP)=%{y}", "hovertext": ["LKA", "LKA", "LKA", "LKA", "LKA", "LKA", "LKA", "LKA", "LKA"], "legendgroup": "Country Name=Sri Lanka", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Country Name=Sri Lanka", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [19.5523202563, 20.8968387282, 19.8164817812, 20.3203983025, 21.0887622908, 21.013103191400003, 21.173983792, 21.8314646398, 23.0385226438], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outline

# %% [markdown]
# # Agriculture, forestry, and fishing, value added (% of GDP) contribution to Economy growth:

# %%
fig = px.bar(
    df_pivot,
    x="Country Name",
    y="NV.AGR.TOTL.ZS",
    title="TOP 10 Countries By 2018 Agriculture, forestry, and fishing, value added (% of GDP)",
    color='Country Name',
    labels={"NV.AGR.TOTL.ZS":"2018 Agriculture, forestry, and fishing, value added (% of GDP)"}
).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="31c46c30-e984-4bde-b619-125332f34dc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("31c46c30-e984-4bde-b619-125332f34dc5")) {
#                     Plotly.newPlot(
#                         '31c46c30-e984-4bde-b619-125332f34dc5',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2018 Agriculture, forestry, and fishing, value added (% of GDP)=%{y}", "legendgroup": "Country Name=Australia", "marker": {"color": "#636efa"}, "name": "Country Name=Australia", "offsetgroup": "Country Name=Australia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [2.4583459558], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2018 Agriculture, forestry, and fishing, value added (% of GDP)=%{y}", "legendgroup": "Country Name=Switzerland", "marker": {"color": "#EF553B"}, "name": "Country Name=Switzerland", "offsetgroup": "Country Name=Switzerland", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Switzerland"], "xaxis": "x", "y": [0.6350243563], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2018 Agriculture, forestry, and fishing, value added (% of GDP)=%{y}", "legendgroup": "Country Name=United Kingdom", "marker": {"color": "#00cc96"}, "name": "Country Name=United Kingdom", "offsetgroup": "Country Name=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [0.5689161226], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2018 Agriculture, forestry, and fishing, value added (% of GDP)=%{y}", "legendgroup": "Country Name=India", "marker": {"color": "#ab63fa"}, "name": "Country Name=India", "offsetgroup": "Country Name=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["India"], "xaxis": "x", "y": [15.9701574809], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2018 Agriculture, forestry, and fishing, value added (% of GDP)=%{y}", "legendgroup": "Country Name=Sri Lanka", "marker": {"color": "#FFA15A"}, "name": "Country Name=Sri Lanka", "offsetgroup": "Country Name=Sri Lanka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sri Lanka"], "xaxis": "x", "y": [8.023787715700001], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.3.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)

# %% [markdown]
# # Industry (including construction), value added (% of GDP) contribution to Economy growth

# %%
fig = px.sunburst(
     df_pivot2, 
     path=['Region', 'Country Name'],
     values='NV.IND.TOTL.ZS',
     title='TOP 10 Countries by 2018 Industry (including construction), value added (% of GDP))',
     hover_name='Country Code',
 )
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-1a53e812a14c> in <module>()
#       3      #path=['Region', 'Country Name'],
#       4      values='NV.IND.TOTL.ZS',
# ----> 5      title='TOP 10 Countries by 2018 Industry (including construction), value added (% of GDP))',
#       6      #hover_name='Country Code',
#       7  )
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in sunburst(data_frame, names, values, parents, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1283     labels=None,
#    1284     color_continuous_scale=None,
# -> 1285     range_color=None,
#    1286     color_continuous_midpoint=None,
#    1287     opacity=None,
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1177                             "All arguments should have the same length. "
#    1178                             "The length of hover_data key `%s` is %d, whereas the "
# -> 1179                             "length of previously-processed arguments %s is %d"
#    1180                             % (
#    1181                                 argument,
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/__init__.py in __init__(self, arg, branchvalues, count, customdata, customdatasrc, domain, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextfont, labels, labelssrc, leaf, level, marker, maxdepth, meta, metasrc, name, opacity, outsidetextfont, parents, parentssrc, stream, text, textfont, textinfo, textsrc, texttemplate, texttemplatesrc, uid, uirevision, values, valuessrc, visible, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    3480         engine: str (default None)
#    3481             The JSON encoding engine to use. One of:
# -> 3482               - "json" for an encoder based on the built-in Python json module
#    3483               - "orjson" for a fast encoder the requires the orjson package
#    3484             If not specified, the default encoder is set to the current value of
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in _set_compound_prop(self, prop, val)
#    3834         """
#    3835         Helper to support the update() methods on :class:`BaseFigure` and
# -> 3836         :class:`BasePlotlyType`
#    3837
#    3838         Parameters
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2439         return self._data_class
#    2440
# -> 2441     def description(self):
#    2442
#    2443         desc = (
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/sunburst/__init__.py in __init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, coloraxis, colorbar, colors, colorscale, colorssrc, line, reversescale, showscale, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/importers.py in __getattr__(import_name)
#      39         raise AttributeError(
#      40             "module {__name__!r} has no attribute {name!r}".format(
# ---> 41                 name=import_name, __name__=parent_name
#      42             )
#      43         )
#
# AttributeError: module 'plotly.validators.sunburst.marker' has no attribute 'ColorBarValidator'

# %% [markdown]
# # Manufacturing, value added (% of GDP) contribution to Economy growth:

# %%
fig = px.scatter(
    df_pivot.dropna(),
    x="NV.IND.MANF.ZS",
    y="NV.IND.MANF.ZS",
    title="TOP 10 Countries by 2018 Manufacturing, value added (% of GDP)",
    labels={"NV.IND.MANF.ZS":"2018 Manufacturing, value added (% of GDP)","NV.IND.MANF.ZS":"2018 Manufacturing, value added (% of GDP)"},
    color='Country Name',
    hover_name='Country Name',
    size_max=100
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ec9532b5-8858-40dd-94b7-2fc8e06e90b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ec9532b5-8858-40dd-94b7-2fc8e06e90b3")) {
#                     Plotly.newPlot(
#                         'ec9532b5-8858-40dd-94b7-2fc8e06e90b3',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>2018 Manufacturing, value added (% of GDP)=%{y}", "hovertext": ["Australia"], "legendgroup": "Country Name=Australia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Country Name=Australia", "showlegend": true, "type": "scatter", "x": [5.7871532436], "xaxis": "x", "y": [5.7871532436], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Switzerland<br>2018 Manufacturing, value added (% of GDP)=%{y}", "hovertext": ["Switzerland"], "legendgroup": "Country Name=Switzerland", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Country Name=Switzerland", "showlegend": true, "type": "scatter", "x": [18.005901759300002], "xaxis": "x", "y": [18.005901759300002], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Kingdom<br>2018 Manufacturing, value added (% of GDP)=%{y}", "hovertext": ["United Kingdom"], "legendgroup": "Country Name=United Kingdom", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Country Name=United Kingdom", "showlegend": true, "type": "scatter", "x": [8.9714594134], "xaxis": "x", "y": [8.9714594134], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>2018 Manufacturing, value added (% of GDP)=%{y}", "hovertext": ["India"], "legendgroup": "Country Name=India", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [14.8532644153], "xaxis": "x", "y": [14.8532644153], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Sri Lanka<br>2018 Manufacturing, value added (% of GDP)=%{y}", "hovertext": ["Sri Lanka"], "legendgroup": "Country Name=Sri Lanka", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Country Name=Sri Lanka", "showlegend": true, "type": "scatter", "x": [15.431328728699999], "xaxis": "x", "y": [15.431328728699999], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %% [markdown]
# # Trade in services (% of GDP) contribution to Economy growth

# %%
fig = px.line(df_pivot2,
    x="Year",
    y="BG.GSR.NFSV.GD.ZS",
    title="TOP 10 Countries by Trade in Services (% of GDP)",
    color='Country Name',
    labels={"Year":"Year","BG.GSR.NFSV.GD.ZS":"Trade in services (% of GDP)"},
    hover_name='Country Code')
#fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4fa46112-2241-4d4b-9e68-f2396118687f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fa46112-2241-4d4b-9e68-f2396118687f")) {
#                     Plotly.newPlot(
#                         '4fa46112-2241-4d4b-9e68-f2396118687f',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>Year=%{x}<br>Trade in services (% of GDP)=%{y}", "hovertext": ["AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS"], "legendgroup": "Country Name=Australia", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Country Name=Australia", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [8.5530166999, 8.206046107899999, 7.7844512222, 7.669459675900001, 8.4693151731, 8.7704678117, 9.967318908300001, 10.054840951100001, 9.9652198445], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Switzerland<br>Year=%{x}<br>Trade in services (% of GDP)=%{y}", "hovertext": ["CHE", "CHE", "CHE", "CHE", "CHE", "CHE", "CHE", "CHE", "CHE"], "legendgroup": "Country Name=Switzerland", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Country Name=Switzerland", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [30.0441093339, 29.3261433014, 31.467473126999998, 31.5348113338, 32.8042535373, 32.764681828899995, 33.906465719699995, 34.80272325, 35.08404217], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Kingdom<br>Year=%{x}<br>Trade in services (% of GDP)=%{y}", "hovertext": ["GBR", "GBR", "GBR", "GBR", "GBR", "GBR", "GBR", "GBR", "GBR"], "legendgroup": "Country Name=United Kingdom", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Country Name=United Kingdom", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [19.3489586126, 20.1757634481, 20.1328597162, 20.7707899032, 20.4311609301, 20.60856815, 21.786213099, 22.655192552600003, 23.778226462600003], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>Trade in services (% of GDP)=%{y}", "hovertext": ["IND", "IND", "IND", "IND", "IND", "IND", "IND", "IND", "IND"], "legendgroup": "Country Name=India", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [11.6960783853, 11.863967708699999, 12.335278235799999, 12.2735572327, 11.6870933049, 11.357798712100001, 11.2315430392, 11.113262784200002, 12.185248883800002], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Sri Lanka<br>Year=%{x}<br>Trade in services (% of GDP)=%{y}", "hovertext": ["LKA", "LKA", "LKA", "LKA", "LKA", "LKA", "LKA", "LKA", "LKA"], "legendgroup": "Country Name=Sri Lanka", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Country Name=Sri Lanka", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [9.8488694757, 10.8676701064, 9.2618958371, 11.0206640675, 11.756856779200001, 12.987609221500001, 13.8311296051, 13.892644998800002, 14.759963486199998], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "

# %% [markdown]
# # GDP per capita, PPP (current international $)

# %%
fig = px.pie(
    df_pivot,
    values='NY.GDP.PCAP.PP.CD', 
    names='Country Name',
    title='TOP 10 Countries by 2018 GDP per capita,PPP(Current International $)',
    hover_name='Country Code',
  )
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8491ddec-abe4-4ce9-b07a-8c84f5117b2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8491ddec-abe4-4ce9-b07a-8c84f5117b2e")) {
#                     Plotly.newPlot(
#                         '8491ddec-abe4-4ce9-b07a-8c84f5117b2e',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=%{label}<br>NY.GDP.PCAP.PP.CD=%{value}", "hovertext": ["AUS", "CHE", "GBR", "IND", "LKA"], "labels": ["Australia", "Switzerland", "United Kingdom", "India", "Sri Lanka"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [50252.840456752405, 68709.4441829587, 47145.8840978145, 6705.149014918199, 13238.3883435355]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...
